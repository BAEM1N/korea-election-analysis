# %% [markdown]
# ## 카토그램
#   - 실제 면적을 기반으로 작성되는 일반적인 지도와는 달리, 특정 통계 정보를 기반으로 작성된 지도를 의미함.
#
#   > Ref] https://namu.wiki/w/%EC%B9%B4%ED%86%A0%EA%B7%B8%EB%9E%A8

# %%
import pandas as pd

# %%
# 미리 준비되어있는 지도를 이용함

election_map = pd.read_excel('../data/korea_map_21th_election_type_b.xlsx')
election_map
# Out:
#      Y       0                1                 2                 3  \
# 0    0     NaN              NaN               NaN               NaN
# 1    1     NaN              NaN               NaN               NaN
# 2    2     NaN              NaN               NaN       인천 중구강화군옹진군
# 3    3     NaN              NaN            인천 서구갑            인천 서구을
# 4    4     NaN              NaN           인천 연수구갑           인천 연수구을
# 5    5     NaN              NaN               NaN               NaN
# 6    6     NaN              NaN        경기 안산시상록구갑           경기 시흥시갑
# 7    7     NaN       경기 안산시상록구을        경기 안산시단원구갑           경기 시흥시을
# 8    8     NaN              NaN        경기 안산시단원구을           경기 부천시갑
# 9    9     NaN              NaN               NaN           경기 부천시정
# 10  10     NaN              NaN               NaN               NaN
# 11  11     NaN              NaN               NaN               NaN
# 12  12     NaN           충남 당진시           충남 천안시갑           충남 천안시을
# 13  13     NaN        충남 서산시태안군      충남 논산시계룡시금산군           충남 천안시병
# 14  14     NaN              NaN           충남 아산시갑           충남 아산시을
# 15  15     NaN              NaN         전북 김제시부안군         충남 홍성군예산군
# 16  16  전북 군산시          전북 전주시갑           전북 전주시을           전북 전주시병
# 17  17     NaN          전북 익산시갑           전북 익산시을            광주 서구갑
# 18  18     NaN  전북 완주군진안군무주군장수군           광주 광산구갑           광주 광산구을
# 19  19     NaN           전남 목포시         전남 나주시화순군   전남 담양군함평군영광군장성군
# 20  20     NaN              NaN      전남 해남군완도군진도군           전남 여수시갑
# 21  21     NaN     전남 영암군무안군신안군  전남 순천시광양시곡성군구례군갑  전남 순천시광양시곡성군구례군을
# 22  22     NaN              NaN               NaN               NaN
#
#                   4                5                6                 7  \
# 0           경기 파주시갑          경기 파주시을              NaN  강원 춘천시철원군화천군양구군갑
# 1           경기 김포시갑          경기 김포시을       경기 동두천시연천군          경기 의정부시갑
# 2           경기 고양시갑          경기 고양시을          경기 고양시병           경기 고양시정
# 3           인천 계양구갑          인천 계양구을       인천 동구미추홀구갑        인천 동구미추홀구을
# 4           인천 부평구갑          인천 부평구을         서울 서대문구갑          서울 서대문구을
# 5           인천 남동구갑          인천 남동구을          서울 마포구갑           서울 마포구을
# 6           서울 강서구갑          서울 양천구갑          서울 양천구을           서울 동작구갑
# 7           서울 강서구을          서울 강서구병         서울 영등포구갑          서울 영등포구을
# 8           경기 부천시을          경기 부천시병          서울 관악구갑           서울 관악구을
# 9           경기 평택시갑          경기 평택시을           서울 금천구           서울 구로구갑
# 22           제주 서귀포시              NaN              NaN         NaN
#
#             12               13            14               15  \
# 0          NaN              NaN           NaN              NaN
# 1          NaN              NaN           NaN              NaN
# 2      강원 원주시을              NaN           NaN              NaN
# 3    경기 포천시가평군  강원 홍천군횡성군영월군평창군           NaN              NaN
# 4       경기 양주시  강원 동해시태백시삼척시정선군           NaN              NaN
# 5      서울 중랑구을           경기 구리시     경기 여주시양평군              NaN
# 6      서울 광진구갑          서울 광진구을        경기 이천시              NaN
# 7      서울 강동구갑          경기 광주시갑       경기 광주시을              NaN
# 8      서울 강동구을          경기 용인시갑       경기 용인시을          경기 용인시정
# 9   경기 성남시분당구을           경기 하남시       경기 용인시병              NaN
# 10   경기 성남시수정구        경기 성남시중원구     경북 상주시문경시  경북 군위군의성군청송군영덕군
# 11      대구 동구갑           대구 동구을  경북 고령군성주군칠곡군           경북 경주시
# 12      대구 북구을          경북 구미시갑       경북 구미시을              NaN
# 13   경북 안동시예천군      경북 포항시남구울릉군      경북 포항시북구              NaN
# 14   경북 영천시청도군           경북 경산시           NaN              NaN
# 15       울산 북구           울산 울주군           NaN              NaN
# 16      울산 남구갑           울산 남구을           NaN              NaN
# 17     부산 사하구을           부산 동래구           NaN              NaN
# 18     부산 서구동구              NaN           NaN              NaN
# 19         NaN              NaN           NaN              NaN
# 20         NaN              NaN           NaN              NaN
# 21         NaN              NaN           NaN              NaN
# 22         NaN              NaN           NaN              NaN
#
#                  16
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10  경북 영주시영양군봉화군울진군
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN

# %%
election_map = election_map.set_index('Y')

election_map = election_map.fillna(0)

col = election_map.columns
idx = election_map.index

# %%
# 카토그램에서 X, Y좌표 및 선거구 명 추출

X = []
Y = []
SIDO = []
SIGUNGU = []

for c in col:
    for i in idx:
        if election_map.loc[i, c]:
            X.append(c)
            Y.append(i)

            loc = election_map.loc[i, c].replace('\n', ' ').replace('  ', ' ').split()
            SIDO.append(loc[0])
            SIGUNGU.append(loc[1])

# %%
df = pd.DataFrame({
    'X' : X,
    'Y' : Y,
    '시도명': SIDO,
    '선거구명': SIGUNGU,
})

df.to_excel('../data/korea_map_21th_election_type_b_data.xlsx', index=False)

# %%
df[df['시도명'] == '광주']
# Out:
#     X   Y 시도명   선거구명
# 20  2  18  광주   광산구갑
# 36  3  17  광주    서구갑
# 37  3  18  광주   광산구을
# 58  4  17  광주    서구을
# 59  4  18  광주  동구남구갑
# 79  5  17  광주    북구갑
# 80  5  18  광주  동구남구을
# 98  6  17  광주    북구을
